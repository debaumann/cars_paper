# %%
import numpy as np 
import matplotlib.pyplot as plt
import csv 
import sys
import os
import pandas as pd

# %%
# Load the CSV file
def eval_set(csv_file_path):
    df = pd.read_csv(csv_file_path, header=None, names=['id', 'videos', 'unknown', 'time_range', 'empty_list', 'annotations'], skiprows=10)
    print(df.head())    
    # Extract the label "close box"
    df['annotations'] = df['annotations'].apply(eval)  # Convert string representation of dictionary to actual dictionary

    # Collect all unique entries from the 'annotations' column
    unique_annotations = set()
    df['annotations'].apply(lambda x: unique_annotations.update(x.values()))
    # Count the occurrences of each unique annotation
    annotation_counts = {annotation: 0 for annotation in unique_annotations}
    df['annotations'].apply(lambda x: [annotation_counts.update({v: annotation_counts[v] + 1}) for v in x.values()])

    # Plot the counts
  
    # total num of annotations
    total_num_annotations = sum(annotation_counts.values())
    
    return annotation_counts

# %%
csv_base = '/Users/dennisbaumann/cars_paper/data/Arctic_Annotations/CSV/'

csv_files = []

for file in sorted(os.listdir(csv_base)):
    if file.endswith(".csv"):
        csv_files.append(csv_base + file)
csv_dict = {}

for i,csv_file in enumerate(csv_files):
    csv_dict[f'S{i+1:02d}'] = eval_set(csv_file)
print(csv_dict)
# Out:
#            id               videos  unknown         time_range empty_list  \
# 0  1_M2Sgz7U3  ["box_grab_01.mp4"]        0   [1.7105,2.48134]         []
# 1  1_S9ZmzwSQ  ["box_grab_01.mp4"]        0  [2.98134,3.91884]         []
# 2  1_UyF46fth  ["box_grab_01.mp4"]        0   [4.62717,5.5855]         []
# 3  1_P7LkutCY  ["box_grab_01.mp4"]        0   [5.60634,6.4605]         []
# 4  1_iCKtqfX3  ["box_grab_01.mp4"]        0    [7.273,8.12717]         []
#
#          annotations
# 0   {"1":"grab box"}
# 1  {"1":"place box"}
# 2   {"1":"grab box"}
# 3  {"1":"place box"}
# 4   {"1":"grab box"}
#            id               videos  unknown           time_range empty_list  \
# 0  1_A05aAnqX  ["box_grab_01.mp4"]        0    [1.23142,2.62726]         []
# 1  1_8vFqmtsY  ["box_grab_01.mp4"]        0    [3.52309,5.02309]         []
# 2  1_IZx2aGBn  ["box_grab_01.mp4"]        0    [6.23142,7.48142]         []
# 3  1_KHRcEgcX  ["box_grab_01.mp4"]        0   [8.81476,10.10642]         []
# 4  1_AzeF5Wdr  ["box_grab_01.mp4"]        0  [11.48142,12.85642]         []
#
#          annotations
# 0   {"1":"grab box"}
# 1  {"1":"place box"}
# 2   {"1":"grab box"}
# 3  {"1":"place box"}
# 4   {"1":"grab box"}
#            id               videos  unknown         time_range empty_list  \
# 0  1_hqohvGKC  ["box_grab_01.mp4"]        0  [1.25217,2.16884]         []
# 1  1_eRu8bhb1  ["box_grab_01.mp4"]        0  [2.16884,3.62717]         []
# 2  1_d0OC2m46  ["box_grab_01.mp4"]        0  [3.93967,4.93967]         []
# 3  1_S5RXqyqB  ["box_grab_01.mp4"]        0  [4.93967,5.75217]         []
# 4  1_1Phakqor  ["box_grab_01.mp4"]        0    [5.75217,6.358]         []
#
#           annotations
# 0    {"1":"grab box"}
# 1   {"1":"place box"}
# 2    {"1":"grab box"}
# 3   {"1":"place box"}
# 4  {"1":"rotate box"}
#            id               videos  unknown         time_range empty_list  \
# 0  1_TcI0VkFa  ["box_grab_01.mp4"]        0    [0.974,2.02309]         []
# 1  1_x3i7WGk9  ["box_grab_01.mp4"]        0    [2.951,3.96059]         []
# 2  1_WkdIOlm0  ["box_grab_01.mp4"]        0  [4.27309,5.10642]         []
# 3  1_q3X50JGg  ["box_grab_01.mp4"]        0        [6.15,7.15]         []
# 4  1_cVPL6WNF  ["box_grab_01.mp4"]        0    [7.903,9.08559]         []
#
#           annotations
# 0    {"1":"grab box"}
# 1   {"1":"place box"}
# 2  {"1":"rotate box"}
# 3    {"1":"grab box"}
# 4   {"1":"place box"}
#            id               videos  unknown         time_range empty_list  \
# 0  1_atI8Mraf  ["box_grab_01.mp4"]        0   [1.0855,1.87717]         []
# 1  1_kqdjjBWn  ["box_grab_01.mp4"]        0  [1.91884,2.79384]         []
# 2  1_1sDgXFBb  ["box_grab_01.mp4"]        0  [3.87717,4.73134]         []
# 3  1_Nuj071vy  ["box_grab_01.mp4"]        0     [5.2105,6.023]         []
# 4  1_sOjBWKfP  ["box_grab_01.mp4"]        0    [6.29384,7.833]         []
#
#           annotations
# 0    {"1":"grab box"}
# 1   {"1":"place box"}
# 2    {"1":"grab box"}
# 3  {"1":"rotate box"}
# 4   {"1":"place box"}
#            id              videos  unknown         time_range empty_list  \
# 0  1_mvlQxt7f  ["box_use_01.mp4"]        0    [1.491,4.16892]         []
# 1  1_SVid80Dp  ["box_use_01.mp4"]        0    [4.575,6.37726]         []
# 2  1_zAIXFU0x  ["box_use_01.mp4"]        0    [6.523,7.68976]         []
# 3  1_ZtmAA9Fl  ["box_use_01.mp4"]        0    [8.098,9.87726]         []
# 4  1_gLEd0e7p  ["box_use_01.mp4"]        0  [10.703,12.62726]         []
#
#           annotations
# 0    {"1":"open box"}
# 1   {"1":"close box"}
# 2    {"1":"grab box"}
# 3  {"1":"rotate box"}
# 4    {"1":"open box"}
#            id               videos  unknown        time_range empty_list  \
# 0  1_ZdXcIIFQ  ["box_grab_01.mp4"]        0   [1.41884,2.418]         []
# 1  1_dl8KSDvj  ["box_grab_01.mp4"]        0  [2.68967,4.2105]         []
# 2  1_kXCZDdAe  ["box_grab_01.mp4"]        0      [4.273,5.58]         []
# 3  1_RfMtMXBX  ["box_grab_01.mp4"]        0  [7.16884,8.8355]         []
# 4  1_AYxbTT9n  ["box_grab_01.mp4"]        0  [9.29384,11.148]         []
#
#           annotations
# 0    {"1":"grab box"}
# 1  {"1":"rotate box"}
# 2   {"1":"place box"}
# 3    {"1":"grab box"}
# 4   {"1":"place box"}
#            id              videos  unknown         time_range empty_list  \
# 0  1_CuPQOHeB  ["box_use_01.mp4"]        0    [0.994,3.62726]         []
# 1  1_IQ7PmcVO  ["box_use_01.mp4"]        0    [4.127,5.39809]         []
# 2  1_8eeDXSB7  ["box_use_01.mp4"]        0    [5.629,7.37726]         []
# 3  1_9YSVGKoG  ["box_use_01.mp4"]        0  [7.68976,9.54392]         []
# 4  1_TFj7yaaE  ["box_use_01.mp4"]        0   [9.776,10.48142]         []
#
#          annotations
# 0   {"1":"open box"}
# 1  {"1":"close box"}
# 2   {"1":"open box"}
# 3  {"1":"close box"}
# 4   {"1":"grab box"}
#            id                         videos  unknown         time_range  \
# 0  1_HYXsuhxo  ["capsulemachine_use_01.mp4"]        0   [1.4605,2.00217]
# 1  1_tZ3K9y9k  ["capsulemachine_use_01.mp4"]        0    [2.023,2.56467]
# 2  1_tbPY95Kj  ["capsulemachine_use_01.mp4"]        0  [2.60634,3.25217]
# 3  1_J4ti5uwG  ["capsulemachine_use_01.mp4"]        0    [3.273,3.85634]
# 4  1_vXE6PYbz  ["capsulemachine_use_01.mp4"]        0  [5.18967,5.60634]
#
#   empty_list                   annotations
# 0         []   {"1":"open capsulemachine"}
# 1         []  {"1":"close capsulemachine"}
# 2         []   {"1":"open capsulemachine"}
# 3         []  {"1":"close capsulemachine"}
# 4         []   {"1":"open capsulemachine"}
#            id              videos  unknown         time_range empty_list  \
# 0  1_9K6IwijX  ["box_use_01.mp4"]        0    [1.815,3.89809]         []
# 1  1_fF6gtHIa  ["box_use_01.mp4"]        0    [4.518,5.85642]         []
# 2  1_JBtIRLHg  ["box_use_01.mp4"]        0    [6.773,8.23142]         []
# 3  1_3uFPXRXb  ["box_use_01.mp4"]        0    [8.447,9.89809]         []
# 4  1_NvPBKlTq  ["box_use_01.mp4"]        0  [10.007,10.96059]         []
#
#          annotations
# 0   {"1":"open box"}
# 1  {"1":"close box"}
# 2   {"1":"open box"}
# 3  {"1":"close box"}
# 4   {"1":"grab box"}
# {'S01': {'place box': 8, 'rotate waffleiron': 6, 'close capsulemachine': 6, 'rotate espressomachine': 7, 'rotate phone': 12, 'open laptop': 9, 'grab capsulemachine': 7, 'close laptop': 9, 'lever espressomachine': 10, 'rotate ketchup': 10, 'place scissors': 7, 'place laptop': 12, 'place phone': 7, 'rotate notebook': 3, 'close phone': 5, 'grab notebook': 3, 'grab laptop': 14, 'rotate mixer': 9, 'grab espressomachine': 7, 'close box': 6, 'rotate scissors': 2, 'cut scissors': 11, 'open ketchup': 5, 'grab ketchup': 7, 'place espressomachine': 7, 'grab microwave': 10, 'close microwave': 5, 'place notebook': 3, 'rotate capsulemachine': 5, 'open box': 7, 'open notebook': 7, 'place capsulemachine': 6, 'open waffleiron': 8, 'place ketchup': 7, 'shake ketchup': 4, 'rotate laptop': 10, 'grab mixer': 6, 'place waffleiron': 7, 'place mixer': 5, 'open phone': 5, 'type laptop': 8, 'rotate microwave': 4, 'rotate box': 8, 'close waffleiron': 7, 'dial phone': 2, 'grab box': 9, 'grab waffleiron': 7, 'close mixer': 9, 'open capsulemachine': 7, 'place microwave': 6, 'close ketchup': 5, 'open mixer': 8, 'close notebook': 5, 'open microwave': 5, 'grab scissors': 7, 'grab phone': 6}, 'S02': {'place box': 7, 'rotate waffleiron': 2, 'close capsulemachine': 8, 'rotate espressomachine': 8, 'open laptop': 5, 'grab capsulemachine': 9, 'close laptop': 5, 'lever espressomachine': 8, 'place scissors': 8, 'place capsule machine': 4, 'place laptop': 5, 'place phone': 6, 'hold scissors': 2, 'close phone': 8, 'grab notebook': 4, 'grab laptop': 5, 'rotate mixer': 3, 'grab espressomachine': 5, 'close box': 5, 'cut scissors': 15, 'open ketchup': 13, 'grab ketchup': 15, 'close microwave': 12, 'grab microwave': 5, 'place notebook': 4, 'open box': 5, 'open notebook': 6, 'place capsulemachine': 4, 'close espressomachine': 5, 'open waffleiron': 8, 'place ketchup': 14, 'rotate laptop': 2, 'grab mixer': 14, 'use ketchup': 5, 'place waffleiron': 6, 'place mixer': 14, 'open phone': 8, 'type laptop': 6, 'close waffleiron': 8, 'grab box': 7, 'write notebook': 6, 'grab waffleiron': 6, 'close mixer': 18, 'type phone': 7, 'open capsulemachine': 8, 'place microwave': 5, 'close ketchup': 14, 'open mixer': 18, 'close notebook': 6, 'open microwave': 12, 'grab scissors': 7, 'grab phone': 6}, 'S03': {'place box': 8, 'rotate waffleiron': 6, 'close capsulemachine': 31, 'rotate espressomachine': 7, 'rotate phone': 2, 'open laptop': 6, 'grab capsulemachine': 11, 'close laptop': 6, 'lever espressomachine': 27, 'rotate ketchup': 9, 'place scissors': 10, 'place laptop': 9, 'place phone': 9, 'rotate notebook': 7, 'close phone': 4, 'grab notebook': 13, 'grab laptop': 9, 'rotate mixer': 7, 'grab espressomachine': 7, 'close box': 12, 'rotate scissors': 3, 'cut scissors': 10, 'open ketchup': 4, 'grab ketchup': 10, 'place espressomachine': 7, 'grab microwave': 7, 'close microwave': 11, 'place notebook': 12, 'rotate capsulemachine': 14, 'open box': 12, 'open notebook': 16, 'place capsulemachine': 11, 'open waffleiron': 16, 'place ketchup': 11, 'shake ketchup': 1, 'rotate laptop': 6, 'grab mixer': 9, 'place waffleiron': 9, 'place mixer': 10, 'open phone': 4, 'type laptop': 4, 'rotate microwave': 3, 'rotate box': 4, 'close waffleiron': 16, 'dial phone': 6, 'grab box': 9, 'write notebook': 8, 'grab waffleiron': 8, 'close mixer': 12, 'open capsulemachine': 33, 'place microwave': 7, 'close ketchup': 5, 'open mixer': 12, 'close notebook': 16, 'open microwave': 15, 'grab scissors': 10, 'grab phone': 9}, 'S04': {'place box': 7, 'rotate waffleiron': 11, 'close capsulemachine': 13, 'rotate espressomachine': 13, 'rotate phone': 14, 'open laptop': 7, 'grab capsulemachine': 9, 'close laptop': 7, 'lever espressomachine': 19, 'rotate ketchup': 10, 'place scissors': 8, 'place laptop': 9, 'place phone': 7, 'rotate notebook': 16, 'close phone': 5, 'grab notebook': 10, 'grab laptop': 9, 'rotate mixer': 18, 'grab espressomachine': 4, 'close box': 9, 'rotate scissors': 1, 'insert scissors': 2, 'open ketchup': 1, 'cut sci ...

# %%
unique_labels = set()
for subset in csv_dict.values():
    unique_labels.update(subset.keys())

# Initialize a dictionary to store the counts
counts_dict = {label: {'total': 0} for label in unique_labels}
for subset_name, subset in csv_dict.items():
    for label in unique_labels:
        counts_dict[label][subset_name] = subset.get(label, 0)
        counts_dict[label]['total'] += subset.get(label, 0)

# Convert the counts dictionary to a DataFrame
df = pd.DataFrame.from_dict(counts_dict, orient='index').reset_index()
df.rename(columns={'index': 'label'}, inplace=True)

# Save the DataFrame to a CSV file
output_csv_path = '/Users/dennisbaumann/cars_paper/data/Arctic_Annotations/eval.csv'
df.to_csv(output_csv_path, index=False)

# %%
reduced_dict = {}
for label, counts in counts_dict.items():
    if counts['total'] > 20:
        reduced_dict[label] = {k: v for k, v in counts.items() if k != 'total'}
        # Calculate the percentage of the total occurrences for each label
        for subset_name in reduced_dict[label].keys():
            reduced_dict[label][subset_name] = int((counts[subset_name] / counts['total']) * 100)
df = pd.DataFrame.from_dict(reduced_dict, orient='index').reset_index()
df.rename(columns={'index': 'label'}, inplace=True)

# Save the DataFrame to a CSV file
output_csv_path = '/Users/dennisbaumann/cars_paper/data/Arctic_Annotations/reduced_eval.csv'
df.to_csv(output_csv_path, index=False)

# %%
from mpl_toolkits.mplot3d import Axes3D
from itertools import combinations

def generate_train_test_splits(data_dict):
    """
    Generate all possible 7-3 train-test splits for a dictionary containing label distributions.

    Parameters:
        data_dict (dict): A dictionary where each key is a label and the value is another dictionary
                          with keys 's1', 's2', ..., 's10' representing counts or percentages.

    Returns:
        list: A list of dictionaries, each containing 'train' and 'test' keys with the corresponding splits.
    """
    # Generate all combinations of 7 subsets out of 10
    # Remove 'total' entry from the dictionary
    
    subsets = [1,2,4,5,6,7,8,9,10] # s1 to s10 as integers
    combinations_7_3 = list(combinations(subsets,7))

    # Prepare train-test splits
    splits = []
    for train_combination in combinations_7_3:
        test_combination =  [s for s in subsets if s not in train_combination]

        # Generate the train and test data for each label
        train_test_split = {
            'train': {},
            'test': {}
        }

        for label, subset_values in data_dict.items():
            # Sum the values for train and test subsets
            train_sum = sum(subset_values[f'S{s:02d}'] for s in train_combination)
            test_sum = sum(subset_values[f'S{s:02d}'] for s in test_combination)

            # Add to train-test split
            
            train_test_split['train'][label] = train_sum
            train_test_split['test'][label] = test_sum
        combo  = [train_combination, train_test_split]
        splits.append(combo)

    return splits

# Example usage:

# Generate splits
splits = generate_train_test_splits(reduced_dict)

# Print an example split

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


def score_splits(splits):
    scores = []
    for split in splits:
        train_values = list(split[1]['train'].values())
        test_values = list(split[1]['test'].values())
        
        train_mae = mean_absolute_error(train_values, [70] * len(train_values))
        test_mae = mean_absolute_error(test_values, [30] * len(test_values))
        train_abs_error = np.array([abs(70 - v) for v in train_values])
        test_abs_error = np.array([abs(30 - v) for v in test_values])
        cost = sum(train_abs_error**2)/len(train_abs_error) + 5*sum(test_abs_error**2)/len(test_abs_error) + train_mae**2 + test_mae**2
        
        scores.append({'split':split[0],'cost': cost,'train_mae': train_mae, 'test_mae': test_mae, 'train_highest': max(train_abs_error), 'test_highest': max(test_abs_error)})
    
    return scores


# Score the splits
split_scores = score_splits(splits)
best_split = min(split_scores, key=lambda x: x['cost'])
best_split_index = split_scores.index(best_split)
print(best_split)
# Out:
# {'split': (1, 2, 4, 7, 8, 9, 10), 'cost': 963.5945303210464, 'train_mae': 10.689655172413794, 'test_mae': 9.344827586206897, 'train_highest': 27, 'test_highest': 21}

# %%
train_split = splits[best_split_index][1]['train']
test_split = splits[best_split_index][1]['test']

print(train_split)
# Create a DataFrame from the best split
best_split_df = pd.DataFrame({
    'label': train_split.keys(),
    'train_count': train_split.values(),
    'test_count': test_split.values()
})
# Save the DataFrame to a CSV file
best_split_csv_path = '/Users/dennisbaumann/cars_paper/data/Arctic_Annotations/best_split.csv'
best_split_df.to_csv(best_split_csv_path, index=False)

print(best_split_df)
# Out:
# {'close box': 58, 'grab phone': 67, 'grab waffleiron': 70, 'rotate microwave': 76, 'place mixer': 71, 'place ketchup': 67, 'open microwave': 61, 'rotate waffleiron': 65, 'grab scissors': 64, 'open capsulemachine': 59, 'close ketchup': 73, 'open laptop': 59, 'grab notebook': 65, 'rotate ketchup': 65, 'close mixer': 67, 'open notebook': 60, 'place microwave': 63, 'rotate laptop': 64, 'grab microwave': 57, 'close waffleiron': 63, 'grab mixer': 71, 'place scissors': 62, 'rotate phone': 70, 'rotate espressomachine': 70, 'use ketchup': 61, 'place laptop': 59, 'read notebook': 65, 'close phone': 68, 'open box': 58, 'place box': 59, 'grab capsulemachine': 66, 'open phone': 72, 'place notebook': 66, 'grab ketchup': 71, 'grab box': 58, 'grab laptop': 56, 'rotate mixer': 62, 'lever espressomachine': 68, 'open mixer': 67, 'type phone': 46, 'rotate capsulemachine': 58, 'open waffleiron': 66, 'close capsulemachine': 59, 'close notebook': 61, 'knob espressomachine': 48, 'dial phone': 64, 'rotate box': 66, 'type laptop': 68, 'close laptop': 58, 'close microwave': 63, 'open ketchup': 72, 'place waffleiron': 69, 'grab espressomachine': 64, 'place phone': 72, 'cut scissors': 64, 'rotate notebook': 77, 'place espressomachine': 60, 'place capsulemachine': 64}
#                      label  train_count  test_count
# 0                close box           58          38
# 1               grab phone           67          29
# 2          grab waffleiron           70          27
# 3         rotate microwave           76          21
# 4              place mixer           71          26
# 5            place ketchup           67          29
# 6           open microwave           61          35
# 7        rotate waffleiron           65          30
# 8            grab scissors           64          31
# 9      open capsulemachine           59          37
# 10           close ketchup           73          22
# 11             open laptop           59          37
# 12           grab notebook           65          29
# 13          rotate ketchup           65          32
# 14             close mixer           67          30
# 15           open notebook           60          34
# 16         place microwave           63          32
# 17           rotate laptop           64          34
# 18          grab microwave           57          39
# 19        close waffleiron           63          30
# 20              grab mixer           71          25
# 21          place scissors           62          31
# 22            rotate phone           70          24
# 23  rotate espressomachine           70          26
# 24             use ketchup           61          38
# 25            place laptop           59          36
# 26           read notebook           65          33
# 27             close phone           68          27
# 28                open box           58          38
# 29               place box           59          35
# 30     grab capsulemachine           66          29
# 31              open phone           72          23
# 32          place notebook           66          29
# 33            grab ketchup           71          24
# 34                grab box           58          38
# 35             grab laptop           56          39
# 36            rotate mixer           62          35
# 37   lever espressomachine           68          27
# 38              open mixer           67          29
# 39              type phone           46          52
# 40   rotate capsulemachine           58          37
# 41         open waffleiron           66          29
# 42    close capsulemachine           59          35
# 43          close notebook           61          32
# 44    knob espressomachine           48          51
# 45              dial phone           64          34
# 46              rotate box           66          29
# 47             type laptop           68          28
# 48            close laptop           58          37
# 49         close microwave           63          33
# 50            open ketchup           72          20
# 51        place waffleiron           69          26
# 52    grab espressomachine           64          32
# 53             place phone           72          25
# 54            cut scissors           64          31
# 55         rotate notebook           77          20
# 56   place espressomachine           60          36
# 57    place capsulemachine           64          32
